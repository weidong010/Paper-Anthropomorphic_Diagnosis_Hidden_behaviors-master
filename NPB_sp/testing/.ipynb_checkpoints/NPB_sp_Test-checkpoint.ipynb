# %% [markdown]
# # Anomaly detection test|NPB_sp

# %% [markdown]
# ### Import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Sequence alignment

# %%
def caculateMse_R2(x,y,p):
    y_pre = [p(i) for i in x]
    score = r2_score(y, y_pre, multioutput='raw_values')
    return score[0]

def list_set(x,y):
    list=[]
    for i in range(0,len(x)):
        list.append([x[i],y[i]])
    return list

def data_set_fix(list,x):
    n=0;
    data=0;
    for i in range(0,len(list)):
        if n==0:
            if list[i][0]==x:
                n=1
                data=list[i][1]
        else:
            list[i][1]=data
    
    return list

# %%
def align_data_singe(x,y,x1,n):
    
    while True:
        coef = np.polyfit(x,y, n)
        poly_fit = np.poly1d(coef)
        R2 = caculateMse_R2(x,y,poly_fit)
        if n>=19:
            break
        if R2>0.9:
            break
        else:
            n=n+1 
        
    
    data_set = list_set(x,y)
    
    for i in range(0,len(x1)):
         data_set.append([x1[i],poly_fit(x1[i])])
    
    data_set.sort();
    
    return data_set
    
def align_data(x1,y1,x2,y2):
    timeseries1 = align_data_singe(x1,y1,x2,6)
    timeseries2 = align_data_singe(x2,y2,x1,6)
    
    if(len(x1)>len(x2)):
        timeseries2 = data_set_fix(timeseries2,x2[-1])
    else:
        timeseries1 = data_set_fix(timeseries1,x1[-1])
    
    return timeseries1,timeseries2

# %% [markdown]
# ### Sequence attribute and feature evaluation algorithm

# %%
def calculate_attenuate_weight(seqLen1, seqLen2, com_ls):
    weight = 0
    for comlen in com_ls:
        weight = weight + comlen / seqLen1 * comlen / seqLen2
    return 1 - weight

def DTWDistance(s1, s2):
    sdt = np.std(s1, ddof=1) if np.std(s1, ddof=1) > np.std(s2, ddof=1) else np.std(s2, ddof=1)
    l1 = len(s1)
    l2 = len(s2)
    paths = np.full((l1 + 1, l2 + 1), np.inf)
    sub_matrix = np.full((l1, l2), 0)
    max_sub_len = 0

    paths[0, 0] = 0
    for i in range(l1):
        for j in range(l2):
            d = s1[i] - s2[j]
            cost = d ** 2
            paths[i + 1, j + 1] = cost + min(paths[i, j + 1], paths[i + 1, j], paths[i, j])
            if np.abs(s1[i] - s2[j]) < sdt:
                if i == 0 or j == 0:
                    sub_matrix[i][j] = 1
                else:
                    sub_matrix[i][j] = sub_matrix[i - 1][j - 1] + 1
                    max_sub_len = sub_matrix[i][j] if sub_matrix[i][j] > max_sub_len else max_sub_len

    paths = np.sqrt(paths)
    s = paths[l1, l2]

    return s

# %%
def LB_Keogh(s1,s2,r):
    LB_sum=0
    for ind,i in enumerate(s1):
        
        lower_bound=min(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        upper_bound=max(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        
        if i>upper_bound:
            LB_sum=LB_sum+(i-upper_bound)**2
        elif i<lower_bound:
            LB_sum=LB_sum+(i-lower_bound)**2
    
    return math.sqrt(LB_sum)

# %%
def Dtw_LB_conter(data1,data2,r):
    l=LB_Keogh(data1,data2,r)+DTWDistance(data1,data2)
    return l/2

def getMin(a,b):
    if a<b:
        return a
    else:
        return b

# %%
def timeseries_score(s1,s2,w,r):
    
    time_s1_s2 = s2[0][len(s2[0])-1]/s1[0][len(s1[0])-1]
    
    time_sum=0;
    for i in range(math.ceil(len(s1[0])/w)):
        s1_time = sum(s1[0][i:i+w])
        s2_time = sum(s2[0][i:i+w])
        i=i+w
        time_sum =time_sum + s2_time/s1_time    

    time_sum = time_sum/math.ceil(len(s1[0])/w)
    
    heartbeat_s1 = (sum(s1[1])/len(s1[1]))
    heartbeat_s1_s2 = sum(s2[1])/len(s2[1])/(sum(s1[1])/len(s1[1]))
    
    heartbeat_sum=0;
    for i in range(math.ceil(len(s1[1])/w)):
        s1_heartbeat = sum(s1[1][i:i+w])
        s2_heartbeat = sum(s2[1][i:i+w])
        i=i+w
        heartbeat_sum =heartbeat_sum + s2_heartbeat/s1_heartbeat    

    heartbeat_sum = heartbeat_sum/math.ceil(len(s1[1])/w)
    
    slope_sum=0;
    for i in range(math.ceil(getMin(len(s1[1])/r,len(s2[1])/r))):
        
        k=i+r
        if(k>len(s1[1])):
            k=len(s1[1])  
        
        s1_slope = (s1[1][i]-s1[1][k])/(s1[0][i]-s1[0][k])
        s2_slope = (s2[1][i]-s2[1][k])/(s2[0][i]-s2[0][k])
        
        i=i+r
        slope_sum =slope_sum + abs(s2_slope/s1_slope)    

    slope_sum = slope_sum/math.ceil(math.ceil(len(s1[1])/r))

    return [time_s1_s2,time_sum,heartbeat_s1,heartbeat_s1_s2,heartbeat_sum,slope_sum]

# %%
def similar_all(x1,y1,x2,y2,tS1,tS2):
    x_p1 =[ tS1[i][0] for i in range(0,len(tS1))]
    y_p1 =[ tS1[i][1] for i in range(0,len(tS1))]
    x_p2 =[ tS2[i][0] for i in range(0,len(tS2))]
    y_p2 =[ tS2[i][1] for i in range(0,len(tS2))]
    
    feature = timeseries_score([x1,y1],[x2,y2],20,5)
    distent = Dtw_LB_conter(y_p1,y_p2,100)
          
    return feature,distent

# %% [markdown]
# ### Anomaly detection function

# %%
min_time_standard = 0.627461
max_time_standard = 2.002258
min_hr_standard   = 0.872978
max_hr_standard   = 1.013804

def distent_check(h_distence):
    h_standard = 50130352395304.004;
    if h_distence<h_standard:
        return 2;
    else:
        return 1;
    

def dataseries_check(feature):
    
    time_check={}
    if feature[0]>min_time_standard*0.9 and feature[0]<max_time_standard*1.1:
        time_check[0]=2
    else:
        time_check[0]=1
    
    if feature[0]/feature[1]>0.90:
        time_check[1]=2
    else:
        time_check[1]=1

    heart={}
    if feature[3]>min_hr_standard*0.9 and feature[3]<max_hr_standard*1.1 :
        heart[0]=2
    else:
        heart[0]=1
    
    if feature[3]/feature[4]>0.90:
        heart[1]=2
    else:
        heart[1]=1
    
    return [time_check,heart]

# %%
def judge(feature):
    
    judge_distence = distent_check(feature[1])
    judge_dataseries = dataseries_check(feature[0])
    
    assis=0;
    check=0;
    
    print("judge_distence = "+str(judge_distence))
    print(judge_dataseries)
    if(judge_distence==2):
        t=0
        print("judge_dataseries[0][0]:"+str(judge_dataseries[0][0]))
        print("feature[0][0]:"+str(feature[0][0]))
        print("min_time_standard:"+str(min_time_standard))  
        print("judge_dataseries[0][0]:",judge_dataseries[0][0])
        if judge_dataseries[0][0] == 1 and feature[0][0]<min_time_standard*0.9:
            t=2
            check=2
            if judge_dataseries[0][1]==1:
                assis=1;
        print("feature[0][0] = "+str(feature[0][0]))
        if judge_dataseries[1][0]==1 and  t!=2 and feature[0][0]>max_time_standard*1.1:
            check=1
            if judge_dataseries[1][1]==1:
                assis=1;
    
    elif judge_distence==1:
        t=0
        check=1
        if judge_dataseries[0][0]==1 and feature[0][0]<min_time_standard*0.9:
            check=2
            t=2
            if judge_dataseries[0][1]==1:
                assis=1;
        print("feature[0][0]:"+str(feature[0][0]))
        print("max_time_standard:"+str(max_time_standard))  
        if judge_dataseries[1][0]==1 and t!=2 and feature[0][0]>max_time_standard*1.1:
            if t==1:
                check=1
            if judge_dataseries[1][1]==1:
                assis=1;    
    
    if(check==0 and assis==0):
        print("Normal：","Two heartbeat sequences are highly consistent, and the thread status is normal.")
    elif(check==0 and assis==1):
        print("Normal：","Two heartbeat sequences have high consistency. The thread status is normal, yet the local oscillation is intense.")
    elif(check==1 and assis==0):
        print("Memory leak：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.")
    elif(check==1 and assis==1):
        print("Memory leak：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.")    
    elif(check==2 and assis==0):
        print("Shutdown：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown.")
    elif(check==2 and assis==1):
        print("Shutdown：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.")
    return [check,assis]

# %% [markdown]
# ### experiment

# %% [markdown]
# #### Import Data

# %%
data = pd.read_excel('../../Dataset/sp_normal_1.xls',hearder=None,sheet_name=None)
x = data['1']['Timestamp'].copy()[0:999]
y = data['1']['Heartbeat'].copy()[0:999]
x = np.array(x)
y = np.array(y)

# %%
normal = pd.read_excel('../../Dataset/sp_std_normal.xls',hearder=None,sheet_name=None)
len(normal)
# Out:
# 30

# %%
plt.figure(figsize=(10,5))
data = pd.read_excel('../../Dataset/sp_std_normal.xls',hearder=None,sheet_name=None)
k=1 
for i in data: 
    x6 = data[i]['Timestamp'].copy()[0:999]
    y6 = data[i]['Heartbeat'].copy()[0:999]
    label_name = 'Test sequence:'+str(k)
    plt.plot(x6,y6,label=label_name)
    k = k+1
plt.xlabel('Time/us',fontsize=14)
plt.ylabel('Hearrate/HZ',fontsize=14)
plt.legend(loc=0,ncol=3,borderaxespad=0.5)   
plt.show()

# %% [markdown]
# #### Normal thread detection experiment

# %%
SeriesFeature=[]
SeriesResult=[]

def normal_lab():
    
    for i in normal:
        title_times = "Proceed to serial number："+str(i)+":"
        print(title_times)
        x2 = normal[i]['Timestamp'].copy()[0:999]
        y2 = normal[i]['Heartbeat'].copy()[0:999]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature.append(feature)
        
        check=judge(feature)
        
        SeriesResult.append(check)
    
normal_lab()
# Out:
# Proceed to serial number：1:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0412793250583445
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0412793250583445
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.6963211265877324
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.6963211265877324
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：3:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:2.025217363831959
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 2.025217363831959
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：4:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.3441667647278333
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.3441667647278333
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：5:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9696182848895908
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9696182848895908
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：6:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.6341089857148156
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.6341089857148156
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：7:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.9113770489251198
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.9113770489251198
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：8:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.2737023760411463
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.2737023760411463
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：9:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.1174859009409752
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.1174859009409752
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：10:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.7117097853444877
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.7117097853444877
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：11:
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]:2.2495360600290017
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 2.2495360600290017
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：12:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.512321137576688
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.512321137576688
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：13:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0028204986147047
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0028204986147047
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：14:
# judge_distence = 1
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# feature[0][0]:0.647849072188739
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：15:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:2.0271843868918245
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 2.0271843868918245
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：16:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.3233250656704567
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.3233250656704567
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：17:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9907564568127175
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9907564568127175
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：18:
# judge_distence = 1
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# feature[0][0]:0.6399642675792384
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：19:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:2.005453040300621
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 2.005453040300621
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：20:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.30705866408182
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.30705866408182
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：21:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0088387833211463
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0088387833211463
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：22:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.6532961601383875
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.6532961601383875
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：23:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:2.017105912012348
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 2.017105912012348
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：24:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.3335560123094619
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.3335560123094619
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：25:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.988062789061044
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.988062789061044
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：26:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.290778984171783
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.290778984171783
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：27:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.024748959597731
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.024748959597731
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：28:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.6731937247568808
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.6731937247568808
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：29:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:2.002258001447795
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 2.002258001447795
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：30:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.3333218101923479
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.3333218101923479
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.

# %%
def precisionRate(result):
    num=0
    for i in result:
        if i[0]==1:
            num=num+1
    print("Accuracy:",(len(result)-num)/len(result))
precisionRate(SeriesResult)
# Out:
# Accuracy: 0.9333333333333333

# %% [markdown]
# #### Memory leak check test

# %%
abnormal = pd.read_excel('../../Dataset/sp_std_abn.xls',hearder=None,sheet_name=None)
len(abnormal)
# Out:
# 48

# %%
SeriesFeature1=[]
SeriesResult1=[]

def abnormal_lab():
    
    for i in abnormal:
        title_times = "Proceed to serial number："+str(i)+":"
        print(title_times)
        x2 = abnormal[i]['Timestamp'].copy()[1:999]

        y2 = abnormal[i]['Heartbeat'].copy()[1:999]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature1.append(feature)
        
        check=judge(feature)
        
        SeriesResult1.append(check)
    
abnormal_lab()
# Out:
# Proceed to serial number：1:
# judge_distence = 1
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# feature[0][0]:1.3211634465211026
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：2:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8201140012573197
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8201140012573197
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：3:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]:2.644445472115296
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：4:
# judge_distence = 1
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]:1.7304235189291628
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：5:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.2933503997919424
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.2933503997919424
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：6:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.7892657134052896
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.7892657134052896
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：7:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]:2.6402628008741713
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：8:
# judge_distence = 1
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]:1.7055108696796857
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：9:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.2764573987951526
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.2764573987951526
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：10:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.7397867959456248
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.7397867959456248
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：11:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]:2.668892464369456
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：12:
# judge_distence = 1
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]:1.7044602797330233
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：13:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:7.448372054902654
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：14:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:4.009546884150309
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：15:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:17.874497426981822
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：16:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:10.816794649843796
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：17:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:7.393176362206967
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：18:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:4.0069727212912385
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：19:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:18.13624221672876
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：20:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:10.77388392274581
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：21:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:7.6643061779450745
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：22:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:4.132799468500846
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：23:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:18.460032023648232
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：24:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:11.389024139530433
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：25:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:36.479910357594356
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：26:
# judge_distence = 1
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# feature[0][0]:19.31809958832625
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：27:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:88.95691367854832
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：28:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:53.94253234072539
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：29:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:35.09463184938171
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：30:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:19.120819904295352
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：31:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:85.98605409954438
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：32:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:53.78137930623976
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：33:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:37.281264837951824
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：34:
# judge_distence = 1
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# feature[0][0]:19.995421268482623
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：35:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:89.48755317624315
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：36:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:55.12989746846513
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：37:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:40.48140462662505
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：38:
# judge_distence = 1
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# feature[0][0]:21.509673943949917
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：39:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:98.61282154714422
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：40:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:60.00244687412289
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：41:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:42.18628958370631
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：42:
# judge_distence = 1
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# feature[0][0]:22.154869641224334
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：43:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:101.53093253651195
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：44:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:60.749778961736
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：45:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:41.128685707169055
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：46:
# judge_distence = 1
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# feature[0][0]:22.038903879147128
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：47:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:98.33826684023111
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：48:
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]:59.63232831702771
# max_time_standard:2.002258
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.

# %%
def precisionRate1(result):
    num=0
    for i in result:
        if i[0]==1:
            num=num+1
    print("Accuracy:",(num/len(result)))
precisionRate1(SeriesResult1)
# Out:
# Accuracy: 0.8958333333333334

# %% [markdown]
# ### Shutdown test

# %%
shutdown = pd.read_excel('../../Dataset/sp_std_shut.xls',hearder=None,sheet_name=None)
len(shutdown)
# Out:
# 48

# %%
SeriesFeature2=[]
SeriesResult2=[]

def shutdown_lab():
    for i in shutdown:
        title_times = "Proceed to serial number："+str(i)+":"
        print(title_times)
        x2 = shutdown[i]['Timestamp'].copy()[0:len(shutdown[i])]
        y2 = shutdown[i]['Heartbeat'].copy()[0:len(shutdown[i])]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature2.append(feature)
        
        check=judge(feature)
        
        SeriesResult2.append(check)

    
shutdown_lab()
# Out:
# Proceed to serial number：1:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.25999342494154104
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.25999342494154104
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：2:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.2602777641687702
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.2602777641687702
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.26350416733249055
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.26350416733249055
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：4:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.2597539572831822
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.2597539572831822
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：5:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.2627862222305657
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.2627862222305657
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：6:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.26112917929442664
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.26112917929442664
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：7:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.2570953168276167
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.2570953168276167
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：8:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.2591921469259999
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.2591921469259999
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：9:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.24356012858909593
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.24356012858909593
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：10:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.24171215254868222
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.24171215254868222
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：11:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.24513727266025676
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.24513727266025676
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：12:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.24484377596999282
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.24484377596999282
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：13:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.3448860834492134
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.3448860834492134
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：14:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.35427179625011046
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.35427179625011046
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：15:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.3557891878749695
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.3557891878749695
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：16:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.3509492397245252
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.3509492397245252
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：17:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.27735780634804497
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.27735780634804497
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：18:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.2716646115793373
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.2716646115793373
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：19:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.2836114378544797
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.2836114378544797
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：20:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.2775890322896725
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.2775890322896725
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：21:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.2988212971454814
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.2988212971454814
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：22:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.29679795568795214
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.29679795568795214
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：23:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.30280914336054165
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.30280914336054165
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：24:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.3035259437795872
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.3035259437795872
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：25:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.3034595521725852
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.3034595521725852
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：26:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.30247466702319725
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.30247466702319725
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：27:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.2999920787944749
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.2999920787944749
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：28:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.308387640904739
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.308387640904739
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：29:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.3059650340588944
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.3059650340588944
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：30:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.30589337691064744
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.30589337691064744
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：31:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.3071955681541897
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.3071955681541897
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：32:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.3027427517535397
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.3027427517535397
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：33:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.23685114223325798
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.23685114223325798
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：34:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.2404037800175915
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.2404037800175915
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：35:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.24994265138774485
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.24994265138774485
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：36:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.2399443043098226
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.2399443043098226
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：37:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.32268038027281
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.32268038027281
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：38:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.3241036789649869
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.3241036789649869
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：39:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.32606841265909375
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.32606841265909375
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：40:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.3221517657191287
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.3221517657191287
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：41:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.38699438784877915
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.38699438784877915
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：42:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.38887349926351106
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.38887349926351106
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：43:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.3902377323191138
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.3902377323191138
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：44:
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.37260618192857087
# min_time_standard:0.627461
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.37260618192857087
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：45:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.952702390235214
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.952702390235214
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：46:
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9483949485602408
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9483949485602408
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：47:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9537854891756498
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9537854891756498
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：48:
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9491504392606082
# min_time_standard:0.627461
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9491504392606082
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.

# %%
def precisionRate2(result):
    num=0
    for i in result:
        if i[0]==2:
            num=num+1
    print("Accuracy:",(num/len(result)))
precisionRate2(SeriesResult2)
# Out:
# Accuracy: 0.9166666666666666

# %% [markdown]
# ### All result

# %%
def resultValue():
    Result_all_pre=[]
    Result_all_true=[]
    for i in SeriesResult:
        Result_all_pre.append(i[0])
        Result_all_true.append(0)

    for i in SeriesResult1:
        Result_all_pre.append(i[0])
        Result_all_true.append(1)

    for i in SeriesResult2:
        Result_all_pre.append(i[0])
        Result_all_true.append(2)
    
    return [Result_all_pre,Result_all_true]

# %%
from sklearn.metrics import classification_report

# %%
resultvalue = resultValue()
acc_num=0
for i in range(0,100):
    if(resultvalue[0][i]==resultvalue[1][i]):
        acc_num=acc_num+1
print("Accuracy:",acc_num/len(resultvalue[0]))
print(classification_report(resultvalue[1], resultvalue[0], labels=[0, 1, 2]))
# Out:
# Accuracy: 0.7380952380952381
#               precision    recall  f1-score   support
#
#            0       0.76      0.93      0.84        30
#            1       0.96      0.90      0.92        48
#            2       1.00      0.92      0.96        48
#
#     accuracy                           0.91       126
#    macro avg       0.90      0.92      0.91       126
# weighted avg       0.93      0.91      0.92       126
