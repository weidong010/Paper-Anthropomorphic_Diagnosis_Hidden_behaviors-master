# %% [markdown]
# # Anomaly detection test|Jacobi

# %% [markdown]
# ### Import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Sequence alignment

# %%
def caculateMse_R2(x,y,p):
    y_pre = [p(i) for i in x]
    score = r2_score(y, y_pre, multioutput='raw_values')
    return score[0]

def list_set(x,y):
    list=[]
    for i in range(0,len(x)):
        list.append([x[i],y[i]])
    return list

def data_set_fix(list,x):
    n=0;
    data=0;
    for i in range(0,len(list)):
        if n==0:
            if list[i][0]==x:
                n=1
                data=list[i][1]
        else:
            list[i][1]=data
    
    return list

# %%
def align_data_singe(x,y,x1,n):
    
    while True:
        coef = np.polyfit(x,y, n)
        poly_fit = np.poly1d(coef)
        R2 = caculateMse_R2(x,y,poly_fit)
        if n>=19:
            break
        if R2>0.9:
            break
        else:
            n=n+1 
        
    
    data_set = list_set(x,y)
    
    for i in range(0,len(x1)):
         data_set.append([x1[i],poly_fit(x1[i])])
    
    data_set.sort();
    
    return data_set
    
def align_data(x1,y1,x2,y2):
    timeseries1 = align_data_singe(x1,y1,x2,6)
    timeseries2 = align_data_singe(x2,y2,x1,6)
    
    if(len(x1)>len(x2)):
        timeseries2 = data_set_fix(timeseries2,x2[-1])
    else:
        timeseries1 = data_set_fix(timeseries1,x1[-1])
    
    return timeseries1,timeseries2

# %% [markdown]
# ### Sequence attribute and feature evaluation algorithm

# %%
def calculate_attenuate_weight(seqLen1, seqLen2, com_ls):
    weight = 0
    for comlen in com_ls:
        weight = weight + comlen / seqLen1 * comlen / seqLen2
    return 1 - weight

def DTWDistance(s1, s2):
    sdt = np.std(s1, ddof=1) if np.std(s1, ddof=1) > np.std(s2, ddof=1) else np.std(s2, ddof=1)
    l1 = len(s1)
    l2 = len(s2)
    paths = np.full((l1 + 1, l2 + 1), np.inf)
    sub_matrix = np.full((l1, l2), 0)
    max_sub_len = 0

    paths[0, 0] = 0
    for i in range(l1):
        for j in range(l2):
            d = s1[i] - s2[j]
            cost = d ** 2
            paths[i + 1, j + 1] = cost + min(paths[i, j + 1], paths[i + 1, j], paths[i, j])
            if np.abs(s1[i] - s2[j]) < sdt:
                if i == 0 or j == 0:
                    sub_matrix[i][j] = 1
                else:
                    sub_matrix[i][j] = sub_matrix[i - 1][j - 1] + 1
                    max_sub_len = sub_matrix[i][j] if sub_matrix[i][j] > max_sub_len else max_sub_len

    paths = np.sqrt(paths)
    s = paths[l1, l2]

    return s

# %%
def LB_Keogh(s1,s2,r):
    LB_sum=0
    for ind,i in enumerate(s1):
        
        lower_bound=min(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        upper_bound=max(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        
        if i>upper_bound:
            LB_sum=LB_sum+(i-upper_bound)**2
        elif i<lower_bound:
            LB_sum=LB_sum+(i-lower_bound)**2
    
    return math.sqrt(LB_sum)

# %%
def Dtw_LB_conter(data1,data2,r):
    l=LB_Keogh(data1,data2,r)+DTWDistance(data1,data2)
    return l/2

def getMin(a,b):
    if a<b:
        return a
    else:
        return b

# %%
def timeseries_score(s1,s2,w,r):
    
    time_s1_s2 = s2[0][len(s2[0])-1]/s1[0][len(s1[0])-1]
    
    time_sum=0;
    for i in range(math.ceil(len(s1[0])/w)):
        s1_time = sum(s1[0][i:i+w])
        s2_time = sum(s2[0][i:i+w])
        i=i+w
        time_sum =time_sum + s2_time/s1_time    

    time_sum = time_sum/math.ceil(len(s1[0])/w)
    
    heartbeat_s1 = (sum(s1[1])/len(s1[1]))
    heartbeat_s1_s2 = sum(s2[1])/len(s2[1])/(sum(s1[1])/len(s1[1]))
    
    heartbeat_sum=0;
    for i in range(math.ceil(len(s1[1])/w)):
        s1_heartbeat = sum(s1[1][i:i+w])
        s2_heartbeat = sum(s2[1][i:i+w])
        i=i+w
        heartbeat_sum =heartbeat_sum + s2_heartbeat/s1_heartbeat    

    heartbeat_sum = heartbeat_sum/math.ceil(len(s1[1])/w)
    
    slope_sum=0;
    for i in range(math.ceil(getMin(len(s1[1])/r,len(s2[1])/r))):
        
        k=i+r
        if(k>len(s1[1])):
            k=len(s1[1])  
        
        s1_slope = (s1[1][i]-s1[1][k])/(s1[0][i]-s1[0][k])
        s2_slope = (s2[1][i]-s2[1][k])/(s2[0][i]-s2[0][k])
        
        i=i+r
        slope_sum =slope_sum + abs(s2_slope/s1_slope)    

    slope_sum = slope_sum/math.ceil(math.ceil(len(s1[1])/r))

    return [time_s1_s2,time_sum,heartbeat_s1,heartbeat_s1_s2,heartbeat_sum,slope_sum]

# %%
def similar_all(x1,y1,x2,y2,tS1,tS2):
    x_p1 =[ tS1[i][0] for i in range(0,len(tS1))]
    y_p1 =[ tS1[i][1] for i in range(0,len(tS1))]
    x_p2 =[ tS2[i][0] for i in range(0,len(tS2))]
    y_p2 =[ tS2[i][1] for i in range(0,len(tS2))]
    
    feature = timeseries_score([x1,y1],[x2,y2],100,20)
    distent = Dtw_LB_conter(y_p1,y_p2,100)
          
    return feature,distent

# %% [markdown]
# ### Anomaly detection function

# %%
min_time_standard = 0.817649
max_time_standard = 1.055358
min_hr_standard   = 0.981820
max_hr_standard   = 1.408497

def distent_check(h_distence):
    h_standard = 18383645284.886333
                 
    if h_distence<h_standard:
        return 2;
    else:
        return 1;

def dataseries_check(feature):
    
    time_check={}
    if feature[0]>min_time_standard*0.9 and feature[0]<max_time_standard*1.1:
        time_check[0]=2
    else:
        time_check[0]=1
    
    if feature[0]/feature[1]>0.90:
        time_check[1]=2
    else:
        time_check[1]=1
    
    heart={}
    if feature[3]>min_hr_standard*0.9 and feature[3]<max_hr_standard*1.1 :
        heart[0]=2
    else:
        heart[0]=1
    
    if feature[3]/feature[4]>0.90:
        heart[1]=2
    else:
        heart[1]=1
    
    return [time_check,heart]

# %%
def judge(feature):
    
    judge_distence = distent_check(feature[1])
    judge_dataseries = dataseries_check(feature[0])
    
    assis=0;
    check=0;
    
    print("judge_distence = "+str(judge_distence))
    print(judge_dataseries)
    if(judge_distence==2):
        t=0
        print("judge_dataseries[0][0]:"+str(judge_dataseries[0][0]))
        print("feature[0][0]:"+str(feature[0][0]))
        print("min_time_standard:"+str(min_time_standard))  
        print("judge_dataseries[0][0]:",judge_dataseries[0][0])
        if judge_dataseries[0][0] == 1 and feature[0][0]<min_time_standard*0.9:
            t=2
            check=2
            if judge_dataseries[0][1]==1:
                assis=1;
        print("feature[0][0] = "+str(feature[0][0]))
        if judge_dataseries[1][0]==1 and  t!=2 and feature[0][0]>max_time_standard*1.1:
            check=1
            if judge_dataseries[1][1]==1:
                assis=1;
    
    elif judge_distence==1:
        t=0
        check=1
        if judge_dataseries[0][0]==1 and feature[0][0]<min_time_standard*0.9:
            check=2
            t=2
            if judge_dataseries[0][1]==1:
                assis=1;
        print("feature[0][0]:"+str(feature[0][0]))
        print("max_time_standard:"+str(max_time_standard))  
        if judge_dataseries[1][0]==1 and t!=2 and feature[0][0]>max_time_standard*1.1:
            if t==1:
                check=1
            if judge_dataseries[1][1]==1:
                assis=1;    
    
    if(check==0 and assis==0):
        print("Normal：","Two heartbeat sequences are highly consistent, and the thread status is normal.")
    elif(check==0 and assis==1):
        print("Normal：","Two heartbeat sequences have high consistency. The thread status is normal, yet the local oscillation is intense.")
    elif(check==1 and assis==0):
        print("Memory leak：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.")
    elif(check==1 and assis==1):
        print("Memory leak：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.")    
    elif(check==2 and assis==0):
        print("Shutdown：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown.")
    elif(check==2 and assis==1):
        print("Shutdown：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.")
    return [check,assis]

# %% [markdown]
# ### experiment

# %% [markdown]
# #### Import Data

# %%
data = pd.read_excel('../../Dataset/jacobi_normal_1.xlsx',hearder=None,sheet_name=None)
x = data['1']['Timestamp'].copy()[0:999]
y = data['1']['Heartbeat'].copy()[0:999]
x = np.array(x)
y = np.array(y)

# %%
normal = pd.read_excel('../../Dataset/jacobi_std_normal.xlsx',hearder=None,sheet_name=None)
len(normal)
# Out:
# 31

# %%
plt.figure(figsize=(10,5))
data = pd.read_excel('../../Dataset/jacobi_std_normal.xlsx',hearder=None,sheet_name=None)
k=1 
for i in data: 
    x6 = data[i]['0.3'].copy()[0:999]
    y6 = data[i]['0.4'].copy()[0:999]
    label_name = 'Test sequence:'+str(k)
    plt.plot(x6,y6,label=label_name)
    k = k+1
plt.xlabel('Time/us',fontsize=14)
plt.ylabel('Hearrate/HZ',fontsize=14)
plt.legend(loc=0,ncol=3,borderaxespad=0.5)   
plt.show()

# %% [markdown]
# #### Normal thread detection experiment

# %%
SeriesFeature=[]
SeriesResult=[]

def normal_lab():
    
    for i in normal:
        title_times = "Proceed to serial number："+str(i)+"："
        print(title_times)
        x2 = normal[i]['0.3'].copy()[0:999]
        y2 = normal[i]['0.4'].copy()[0:999]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature.append(feature)
        
        check=judge(feature)
        
        SeriesResult.append(check)
    
normal_lab()
# Out:
# Proceed to serial number：1：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2：
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9475451878974632
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9475451878974632
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：3：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8953700780190736
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8953700780190736
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：4：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8942749678373962
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8942749678373962
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：5：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8637332544297859
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8637332544297859
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：6：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8626058938230098
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8626058938230098
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：7：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8168243981135075
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8168243981135075
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：8：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8227522071064042
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8227522071064042
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：9：
# judge_distence = 1
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]:0.7763382630834036
# max_time_standard:1.055358
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：10：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8218089452123274
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8218089452123274
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：11：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8830050137455155
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8830050137455155
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：12：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8332791710529506
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8332791710529506
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：13：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8822949087734686
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8822949087734686
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：14：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8223976698098353
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8223976698098353
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：15：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8216898125419912
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8216898125419912
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：16：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.7747602790860837
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.7747602790860837
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：17：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.798388680419034
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.798388680419034
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：18：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8430748920432454
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8430748920432454
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：19：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8453492600175176
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8453492600175176
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：20：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.7735914163819777
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.7735914163819777
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：21：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8199725621834976
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8199725621834976
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：22：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8199725621834976
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8199725621834976
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：23：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8205522611834718
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8205522611834718
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：24：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8909837854357741
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8909837854357741
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：25：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8910084493157397
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8910084493157397
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：26：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.7992211657113967
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.7992211657113967
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：28：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.7993684707670983
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.7993684707670983
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：29：
# judge_distence = 1
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]:0.753246450044674
# max_time_standard:1.055358
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：30：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9067180104911876
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9067180104911876
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：31：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9064278740502385
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9064278740502385
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：32：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8537966932506165
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8537966932506165
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.

# %%
def precisionRate(result):
    num=0
    for i in result:
        if i[0]==1:
            num=num+1
    print("Accuracy:",(len(result)-num)/len(result))
precisionRate(SeriesResult)
# Out:
# Accuracy: 0.9354838709677419

# %% [markdown]
# #### Memory leak check test

# %%
abnormal = pd.read_excel('../../Dataset/jacobi_std_abn.xlsx',hearder=None,sheet_name=None)
len(abnormal)
# Out:
# 40

# %%
SeriesFeature1=[]
SeriesResult1=[]

def abnormal_lab():
    
    for i in abnormal:
        title_times = "Proceed to serial number："+str(i)+"："
        print(title_times)
        x2 = abnormal[i]['time'].copy()[0:999]

        y2 = abnormal[i]['heartrate'].copy()[0:999]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature1.append(feature)
        
        check=judge(feature)
        
        SeriesResult1.append(check)
    
abnormal_lab()
# Out:
# Proceed to serial number：2_1：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0063452776595523
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0063452776595523
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_2：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0035830665738856
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0035830665738856
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_3：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9501379212167242
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9501379212167242
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_4：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0276166502832071
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0276166502832071
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_5：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.026606087690758
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.026606087690758
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_6：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9673415144201398
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9673415144201398
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_7：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9291404554793011
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9291404554793011
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_8：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9827212065265748
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9827212065265748
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_9：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9834061867740806
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9834061867740806
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_10：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0154124251140608
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0154124251140608
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_11：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0152290567965376
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0152290567965376
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_12：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.1020781212246613
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.1020781212246613
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_13：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0412070220261795
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0412070220261795
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_14：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0963211986174384
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0963211986174384
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_15：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9619043440392223
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9619043440392223
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_16：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9693279284438107
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9693279284438107
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_17：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.911415838355061
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.911415838355061
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_18：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0226119042796948
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0226119042796948
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_19：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0228712336955363
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0228712336955363
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_20：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9666151711981948
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9666151711981948
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_21：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0283885127759507
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0283885127759507
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_22：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0255474103160807
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0255474103160807
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_23：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9747513430489109
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9747513430489109
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_24：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0380255380238685
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0380255380238685
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_25：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0426652299097938
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0426652299097938
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_26：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9864060023666891
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9864060023666891
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_27：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0024840392133172
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0024840392133172
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_28：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0026015067565555
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0026015067565555
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_29：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9498996645712324
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9498996645712324
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_30：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0181226085861987
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0181226085861987
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_31：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0181226085861987
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0181226085861987
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_32：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9625601736935377
# min_time_standard:0.817649
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9625601736935377
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2_33：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.624873441645373
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.624873441645373
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：2_34：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.6244236182114506
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.6244236182114506
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：2_35：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.6237005748105695
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.6237005748105695
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：2_36：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.6223992758097048
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.6223992758097048
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：2_37：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.6182001730758322
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.6182001730758322
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：2_38：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.6182001730758322
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.6182001730758322
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：2_39：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.6129890165260257
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.6129890165260257
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：2_40：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.6175608468744251
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.6175608468744251
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.

# %%
plt.figure(figsize=(10,5))
data = pd.read_excel('../../Dataset/jacobi_std_abn.xlsx',hearder=None,sheet_name=None)
k=1 
for i in data: 
    x6 = data[i]['time'].copy()[0:999]
    y6 = data[i]['heartrate'].copy()[0:999]
    label_name = 'Test sequence:'+str(k)
    plt.plot(x6,y6,label=label_name)
    k = k+1
plt.xlabel('Time/us',fontsize=14)
plt.ylabel('Hearrate/HZ',fontsize=14)
plt.legend(loc=0,ncol=3,borderaxespad=0.5)   
plt.show()

# %%
def precisionRate1(result):
    num=0
    for i in result:
        if i[0]==1:
            num=num+1
    print("Accuracy:",(num/len(result)))
precisionRate1(SeriesResult1)
# Out:
# Accuracy: 0.2

# %% [markdown]
# ### Shutdown test

# %%
shutdown = pd.read_excel('../../Dataset/jacobi_std_shut.xlsx',hearder=None,sheet_name=None)
len(shutdown)
# Out:
# 31

# %%
SeriesFeature2=[]
SeriesResult2=[]

def shutdown_lab():
    for i in shutdown:
        title_times = "Proceed to serial number："+str(i)+"："
        print(title_times)
        x2 = shutdown[i]['time'].copy()[0:len(shutdown[i])]

        y2 = shutdown[i]['heartrate'].copy()[0:len(shutdown[i])]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature2.append(feature)
        
        check=judge(feature)
        
        SeriesResult2.append(check)

    
shutdown_lab()
# Out:
# Proceed to serial number：3_1：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.1544683498727843
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.1544683498727843
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_2：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.15449009217204535
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.15449009217204535
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_3：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.1339277419704441
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.1339277419704441
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_4：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.164149207526451
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.164149207526451
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_5：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.16415660277760938
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.16415660277760938
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_6：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.143441708673954
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.143441708673954
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_7：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.14283092440309064
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.14283092440309064
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_8：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.14280865604539913
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.14280865604539913
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_9：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.1252967491258474
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.1252967491258474
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_10：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.10571555876326567
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.10571555876326567
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown.
# Proceed to serial number：3_11：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.08790313335704683
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.08790313335704683
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_12：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.08867253946125148
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.08867253946125148
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_13：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.08576409282710548
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.08576409282710548
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_14：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.1605499331357997
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.1605499331357997
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_15：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.1602972903138922
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.1602972903138922
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_16：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.13896658177735685
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.13896658177735685
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_17：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.15911172851531286
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.15911172851531286
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_18：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.1591028942117539
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.1591028942117539
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_19：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.13691777548480066
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.13691777548480066
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_20：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.19299845184047237
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.19299845184047237
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_21：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.19300970340425713
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.19300970340425713
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_22：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.17772414967132738
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.17772414967132738
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_23：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.15053751085288974
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.15053751085288974
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_24：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.1505302460294414
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.1505302460294414
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_25：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.1289490032523106
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.1289490032523106
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_26：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.09203679181361957
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.09203679181361957
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_27：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.09428374388324473
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.09428374388324473
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_28：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.0838191722055837
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.0838191722055837
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_29：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.041190262065441394
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.041190262065441394
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_30：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.038253812601953166
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.038253812601953166
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：3_31：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.027590256062288657
# min_time_standard:0.817649
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.027590256062288657
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.

# %%
def precisionRate2(result):
    num=0
    for i in result:
        if i[0]==2:
            num=num+1
    print("Accuracy:",(num/len(result)))
precisionRate2(SeriesResult2)
# Out:
# Accuracy: 1.0

# %% [markdown]
# ### All result

# %%
def resultValue():
    Result_all_pre=[]
    Result_all_true=[]
    for i in SeriesResult:
        Result_all_pre.append(i[0])
        Result_all_true.append(0)

    for i in SeriesResult1:
        Result_all_pre.append(i[0])
        Result_all_true.append(1)

    for i in SeriesResult2:
        Result_all_pre.append(i[0])
        Result_all_true.append(2)
    
    return [Result_all_pre,Result_all_true]

# %%
from sklearn.metrics import classification_report

# %%
resultvalue = resultValue()
acc_num=0
for i in range(0,100):
    if(resultvalue[0][i]==resultvalue[1][i]):
        acc_num=acc_num+1

print("Accuracy:",acc_num/len(resultvalue[0]))

print(classification_report(resultvalue[1], resultvalue[0], labels=[0, 1, 2]))
# Out:
# Accuracy: 0.6470588235294118
#               precision    recall  f1-score   support
#
#            0       0.48      0.94      0.63        31
#            1       0.80      0.20      0.32        40
#            2       1.00      1.00      1.00        31
#
#     accuracy                           0.67       102
#    macro avg       0.76      0.71      0.65       102
# weighted avg       0.76      0.67      0.62       102
