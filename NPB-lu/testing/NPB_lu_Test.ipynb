# %% [markdown]
# # Anomaly detection test|NPB_lu

# %% [markdown]
# ### Import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Sequence alignment

# %%
def caculateMse_R2(x,y,p):
    y_pre = [p(i) for i in x]
    score = r2_score(y, y_pre, multioutput='raw_values')
    return score[0]

def list_set(x,y):
    list=[]
    for i in range(0,len(x)):
        list.append([x[i],y[i]])
    return list

def data_set_fix(list,x):
    n=0;
    data=0;
    for i in range(0,len(list)):
        if n==0:
            if list[i][0]==x:
                n=1
                data=list[i][1]
        else:
            list[i][1]=data
    
    return list

# %%
def align_data_singe(x,y,x1,n):
    
    while True:
        coef = np.polyfit(x,y, n)
        poly_fit = np.poly1d(coef)
        R2 = caculateMse_R2(x,y,poly_fit)
        if n>=19:
            break
        if R2>0.9:
            break
        else:
            n=n+1 
        
    
    data_set = list_set(x,y)
    
    for i in range(0,len(x1)):
         data_set.append([x1[i],poly_fit(x1[i])])
    
    data_set.sort();
    
    return data_set
    
def align_data(x1,y1,x2,y2):
    timeseries1 = align_data_singe(x1,y1,x2,6)
    timeseries2 = align_data_singe(x2,y2,x1,6)
    
    if(len(x1)>len(x2)):
        timeseries2 = data_set_fix(timeseries2,x2[-1])
    else:
        timeseries1 = data_set_fix(timeseries1,x1[-1])
    
    return timeseries1,timeseries2

# %% [markdown]
# ### Sequence attribute and feature evaluation algorithm

# %%
def calculate_attenuate_weight(seqLen1, seqLen2, com_ls):
    weight = 0
    for comlen in com_ls:
        weight = weight + comlen / seqLen1 * comlen / seqLen2
    return 1 - weight

def DTWDistance(s1, s2):
    sdt = np.std(s1, ddof=1) if np.std(s1, ddof=1) > np.std(s2, ddof=1) else np.std(s2, ddof=1)
    l1 = len(s1)
    l2 = len(s2)
    paths = np.full((l1 + 1, l2 + 1), np.inf)
    sub_matrix = np.full((l1, l2), 0)
    max_sub_len = 0

    paths[0, 0] = 0
    for i in range(l1):
        for j in range(l2):
            d = s1[i] - s2[j]
            cost = d ** 2
            paths[i + 1, j + 1] = cost + min(paths[i, j + 1], paths[i + 1, j], paths[i, j])
            if np.abs(s1[i] - s2[j]) < sdt:
                if i == 0 or j == 0:
                    sub_matrix[i][j] = 1
                else:
                    sub_matrix[i][j] = sub_matrix[i - 1][j - 1] + 1
                    max_sub_len = sub_matrix[i][j] if sub_matrix[i][j] > max_sub_len else max_sub_len

    paths = np.sqrt(paths)
    s = paths[l1, l2]

    return s

# %%
def LB_Keogh(s1,s2,r):
    LB_sum=0
    for ind,i in enumerate(s1):
        
        lower_bound=min(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        upper_bound=max(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        
        if i>upper_bound:
            LB_sum=LB_sum+(i-upper_bound)**2
        elif i<lower_bound:
            LB_sum=LB_sum+(i-lower_bound)**2
    
    return math.sqrt(LB_sum)

# %%
def Dtw_LB_conter(data1,data2,r):
    l=LB_Keogh(data1,data2,r)+DTWDistance(data1,data2)
    return l/2

def getMin(a,b):
    if a<b:
        return a
    else:
        return b

# %%
def timeseries_score(s1,s2,w,r):
    
    time_s1_s2 = s2[0][len(s2[0])-1]/s1[0][len(s1[0])-1]
    
    time_sum=0;
    for i in range(math.ceil(len(s1[0])/w)):
        s1_time = sum(s1[0][i:i+w])
        s2_time = sum(s2[0][i:i+w])
        i=i+w
        time_sum =time_sum + s2_time/s1_time    

    time_sum = time_sum/math.ceil(len(s1[0])/w)
    
    heartbeat_s1 = (sum(s1[1])/len(s1[1]))
    heartbeat_s1_s2 = sum(s2[1])/len(s2[1])/(sum(s1[1])/len(s1[1]))
    
    heartbeat_sum=0;
    for i in range(math.ceil(len(s1[1])/w)):
        s1_heartbeat = sum(s1[1][i:i+w])
        s2_heartbeat = sum(s2[1][i:i+w])
        i=i+w
        heartbeat_sum =heartbeat_sum + s2_heartbeat/s1_heartbeat    

    heartbeat_sum = heartbeat_sum/math.ceil(len(s1[1])/w)
    
    slope_sum=0;
    for i in range(math.ceil(getMin(len(s1[1])/r,len(s2[1])/r))):
        
        k=i+r
        if(k>len(s1[1])):
            k=len(s1[1])  
        
        s1_slope = (s1[1][i]-s1[1][k])/(s1[0][i]-s1[0][k])
        s2_slope = (s2[1][i]-s2[1][k])/(s2[0][i]-s2[0][k])
        
        i=i+r
        slope_sum =slope_sum + abs(s2_slope/s1_slope)    

    slope_sum = slope_sum/math.ceil(math.ceil(len(s1[1])/r))

    return [time_s1_s2,time_sum,heartbeat_s1,heartbeat_s1_s2,heartbeat_sum,slope_sum]

# %%
def similar_all(x1,y1,x2,y2,tS1,tS2):
    x_p1 =[ tS1[i][0] for i in range(0,len(tS1))]
    y_p1 =[ tS1[i][1] for i in range(0,len(tS1))]
    x_p2 =[ tS2[i][0] for i in range(0,len(tS2))]
    y_p2 =[ tS2[i][1] for i in range(0,len(tS2))]
    
    feature = timeseries_score([x1,y1],[x2,y2],100,2)
    distent = Dtw_LB_conter(y_p1,y_p2,100)
    
    return feature,distent

# %% [markdown]
# ### Anomaly diagnosis function

# %%
min_time_standard = 0.92570
max_time_standard = 1.08025
min_hr_standard = 0.94607 
max_hr_standard = 1.05700

def distent_check(h_distence):
    h_standard = 11173623.48358;
    if h_distence<h_standard:
        return 2;
    else:
        return 1;

def dataseries_check(feature):
    
    time_check={}
    if feature[0]>min_time_standard*0.9 and feature[0]<max_time_standard*1.1:
        time_check[0]=2
    else:
        time_check[0]=1
    
    if feature[0]/feature[1]>0.90:
        print(feature[0]/feature[1])
        time_check[1]=2
    else:
        time_check[1]=1
    
    heart={}
    if feature[3]>min_hr_standard*0.9 and feature[3]<max_hr_standard*1.1 :
        heart[0]=2
    else:
        heart[0]=1
    
    if feature[3]/feature[4]>0.90:
        heart[1]=2
    else:
        heart[1]=1
    
    return [time_check,heart]

# %%
def judge(feature):
    
    judge_distence = distent_check(feature[1])
    judge_dataseries = dataseries_check(feature[0])
    
    assis=0;
    check=0;
    
    print("judge_distence = "+str(judge_distence))
    print(judge_dataseries)
    if(judge_distence==2):
        t=0
        print("judge_dataseries[0][0]:"+str(judge_dataseries[0][0]))
        print("feature[0][0]:"+str(feature[0][0]))
        print("min_time_standard:"+str(min_time_standard))  
        print("judge_dataseries[0][0]:",judge_dataseries[0][0])
        if judge_dataseries[0][0] == 1 and feature[0][0]<min_time_standard*0.9:
            t=2
            check=2
            if judge_dataseries[0][1]==1:
                assis=1;
        print("feature[0][0] = "+str(feature[0][0]))
        if judge_dataseries[1][0]==1 and  t!=2 and feature[0][0]>max_time_standard*1.1:
            check=1
            if judge_dataseries[1][1]==1:
                assis=1;
    
    elif judge_distence==1:
        t=0
        check=1
        if judge_dataseries[0][0]==1 and feature[0][0]<min_time_standard*0.9:
            check=2
            t=2
            if judge_dataseries[0][1]==1:
                assis=1;
        print("feature[0][0]:"+str(feature[0][0]))
        print("max_time_standard:"+str(max_time_standard))  
        if judge_dataseries[1][0]==1 and t!=2 and feature[0][0]>max_time_standard*1.1:
            if t==1:
                check=1
            if judge_dataseries[1][1]==1:
                assis=1;    
    
    if(check==0 and assis==0):
        print("Normal：","Two heartbeat sequences are highly consistent, and the thread status is normal.")
    elif(check==0 and assis==1):
        print("Normal：","Two heartbeat sequences have high consistency. The thread status is normal, yet the local oscillation is intense.")
    elif(check==1 and assis==0):
        print("Memory leak：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.")
    elif(check==1 and assis==1):
        print("Memory leak：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.")    
    elif(check==2 and assis==0):
        print("Shutdown：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown.")
    elif(check==2 and assis==1):
        print("Shutdown：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.")
    return [check,assis]

# %% [markdown]
# ### experiment

# %% [markdown]
# #### Import Data

# %%
normal = pd.read_excel('../../Dataset/normal_lu_1.xlsx',hearder=None,sheet_name=None)
lab_normal = pd.read_excel('../../Dataset/lu_std_normal.xlsx',hearder=None,sheet_name=None)
lab_abnormal = pd.read_excel('../../Dataset/lu_std_abs.xlsx',hearder=None,sheet_name=None)
lab_shutdown = pd.read_excel('../../Dataset/lu_std_shut.xlsx',hearder=None,sheet_name=None)
print(len(normal),len(lab_normal),len(lab_abnormal),len(lab_shutdown))
# Out:
# 1 30 32 34

# %%
x = normal['1']['time'].copy()[0:999]
y = normal['1']['heartrate'].copy()[0:999]
x = np.array(x)
y = np.array(y)

# %% [markdown]
# #### Normal thread detection experiment

# %%
SeriesFeature=[]
SeriesResult=[]

def normal_lab():
    
    for i in range(len(lab_normal)):
        title_times = "Proceed to serial number："+str(i+1)+"："
        print(title_times)
        x2 = lab_normal[str(i+1)]['time'].copy()[0:999]

        y2 = lab_normal[str(i+1)]['heartrate'].copy()[0:999]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature.append(feature)
        
        check=judge(feature)
        
        SeriesResult.append(check)
    
normal_lab()
# Out:
# Proceed to serial number：1：
# 0.974349214234748
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0045070845672106
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0045070845672106
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：2：
# 0.9755126234884274
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.002189261690018
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.002189261690018
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：3：
# 1.0314978626365414
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0566975134574805
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0566975134574805
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：4：
# 0.9887054721876088
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0113651472651484
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0113651472651484
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：5：
# 1.0136709718640504
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0127955596319225
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0127955596319225
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：6：
# 1.0
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：7：
# 0.9752136531586773
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9781889179580018
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9781889179580018
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：8：
# 1.0396797511909186
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0229018222195005
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0229018222195005
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：9：
# 1.0171614911691302
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9905351900726405
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9905351900726405
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：10：
# 1.0011293493085383
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9837146807741143
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9837146807741143
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：11：
# 0.9669272327095667
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9704339718200644
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9704339718200644
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：12：
# 0.9740662591313424
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9904008774639343
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9904008774639343
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：13：
# 0.977157483924655
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0061404882821552
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0061404882821552
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：14：
# 0.9664477459267605
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9858968377669463
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9858968377669463
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：15：
# 0.9588034361440495
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9780928353865345
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9780928353865345
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：16：
# 0.9996302679139942
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.00974730622023
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.00974730622023
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：17：
# 0.9739328036040196
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9820372956003993
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9820372956003993
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：18：
# 0.9982803141089927
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0161026270125324
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0161026270125324
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：19：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.2079595614168932
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.2079595614168932
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：20：
# 0.9680343147550846
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.024659388975743
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.024659388975743
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：21：
# 0.9768082176582775
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0344334223901488
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0344334223901488
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：22：
# 0.9063941969145346
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.2280597647127283
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.2280597647127283
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：23：
# 1.024066265552015
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0008457972840434
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0008457972840434
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：24：
# 1.0579852476471114
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4168068716631184
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4168068716631184
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：25：
# 1.0543279355279405
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4118136228170395
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4118136228170395
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：26：
# 1.0250479343056644
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9913525685679401
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9913525685679401
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：27：
# 0.9876219387731118
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9969571596909254
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9969571596909254
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：28：
# 0.9794953208085153
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0034667539078372
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0034667539078372
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：29：
# 1.000591946051585
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0071811572604423
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0071811572604423
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：30：
# 0.9873993272446194
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.9960477584511219
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.9960477584511219
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.

# %%
def precisionRate(result):
    num=0
    for i in result:
        if i[0]==1:
            num=num+1
    print("Accuracy:",(len(result)-num)/len(result))
precisionRate(SeriesResult)
# Out:
# Accuracy: 0.8666666666666667

# %% [markdown]
# #### Memory leak check test

# %%
SeriesFeature1=[]
SeriesResult1=[]

def abnormal_lab():
    
    for i in range(len(lab_abnormal)):
        title_times = "Proceed to serial number："+str(i+1)+"："
        print(title_times)

        x2 = lab_abnormal[str(i+1)]['time'].copy()[0:999]
        y2 = lab_abnormal[str(i+1)]['heartrate'].copy()[0:999]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature1.append(feature)
        
        check=judge(feature)
        
        SeriesResult1.append(check)
    
abnormal_lab()
# Out:
# Proceed to serial number：1：
# 52.69019792821047
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:45.07931210291932
# max_time_standard:1.08025
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：2：
# 71.66831659726857
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:45.05750744893668
# max_time_standard:1.08025
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：3：
# 93.96672144315694
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:57.369326857007145
# max_time_standard:1.08025
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：4：
# 93.96672144315694
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:57.369326857007145
# max_time_standard:1.08025
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：5：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4787297207414192
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4787297207414192
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：6：
# 1.042722013297042
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.476395658556373
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.476395658556373
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：7：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4647832001653702
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4647832001653702
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：8：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.3813601841266856
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.3813601841266856
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：9：
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0272972615452176
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0272972615452176
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：10：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4841262457325297
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4841262457325297
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：11：
# 1.031831272241906
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4656364404655133
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4656364404655133
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：12：
# 1.0105725592325887
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4971346079611176
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4971346079611176
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：13：
# 1.025430171347576
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.5730337496798656
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.5730337496798656
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：14：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.314724214262781
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.314724214262781
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：15：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.293600934572167
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.293600934572167
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：16：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4851239482087875
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4851239482087875
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：17：
# 0.901882780444621
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4712308820210902
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4712308820210902
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：18：
# 0.9370552980900781
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.309621688407604
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.309621688407604
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：19：
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.0270323578358551
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.0270323578358551
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：20：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.469819077194565
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.469819077194565
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：21：
# 1.0357220663344944
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4828771723034544
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4828771723034544
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：22：
# 1.1621902098861192
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4139020654707994
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4139020654707994
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：23：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4721003616290869
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4721003616290869
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：24：
# 1.0376428812846978
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4636244578862307
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4636244578862307
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：25：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.273452013352771
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.273452013352771
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：26：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.2800397592387283
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.2800397592387283
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：27：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4893262074348288
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4893262074348288
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：28：
# 1.0773044764641015
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4529897411555823
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4529897411555823
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：29：
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:1.1653005912799654
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 1.1653005912799654
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：30：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.4652284278556909
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.4652284278556909
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：31：
# 1.1652332830442937
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.6648934244674267
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.6648934244674267
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.
# Proceed to serial number：32：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:1.5036103702866677
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 1.5036103702866677
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.

# %%
def precisionRate1(result):
    num=0
    for i in result:
        if i[0]==1:
            num=num+1
    print("Accuracy:",(num/len(result)))
precisionRate1(SeriesResult1)
# Out:
# Accuracy: 0.90625

# %% [markdown]
# ### Shutdown test

# %%
SeriesFeature2=[]
SeriesResult2=[]

def shutdown_lab():
    
    for i in range(len(lab_shutdown)):
        title_times = "Proceed to serial number："+str(i+1)+"："
        print(title_times)
        lenth = len(lab_shutdown[str(i+1)]['time'])
        x2 = lab_shutdown[str(i+1)]['time'].copy()[1:lenth]

        y2 = lab_shutdown[str(i+1)]['heartrate'].copy()[1:lenth]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature2.append(feature)
        
        check=judge(feature)
        
        SeriesResult2.append(check)
    

    
shutdown_lab()
# Out:
# Proceed to serial number：1：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.5634782702836567
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.5634782702836567
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：2：
# judge_distence = 1
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# feature[0][0]:1.5693484417538317
# max_time_standard:1.08025
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：3：
# judge_distence = 1
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# feature[0][0]:1.5689340010846504
# max_time_standard:1.08025
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：4：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.5367453246863529
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.5367453246863529
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：5：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.7869189668687671
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.7869189668687671
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：6：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.7990118381171064
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.7990118381171064
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：7：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.7560358631581191
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.7560358631581191
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：8：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.7448276958688892
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.7448276958688892
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：9：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.7628692285753628
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.7628692285753628
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：10：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.7261274562376028
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.7261274562376028
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：11：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.7467791193626342
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.7467791193626342
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：12：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.7419310093304973
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.7419310093304973
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：13：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.7455303842524725
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.7455303842524725
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：14：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.755544285776633
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.755544285776633
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：15：
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8610128388644529
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8610128388644529
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：16：
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]:0.8534541176964136
# min_time_standard:0.9257
# judge_dataseries[0][0]: 2
# feature[0][0] = 0.8534541176964136
# Normal： Two heartbeat sequences are highly consistent, and the thread status is normal.
# Proceed to serial number：17：
# 0.9762518279762621
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:3.507557198732928
# max_time_standard:1.08025
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：18：
# 1.058386845687365
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:3.4080616660650227
# max_time_standard:1.08025
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：19：
# judge_distence = 1
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# feature[0][0]:1.7704665180995545
# max_time_standard:1.08025
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：20：
# judge_distence = 1
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# feature[0][0]:1.7694857315689776
# max_time_standard:1.08025
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：21：
# 1.162372007116021
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# feature[0][0]:3.6376885239856267
# max_time_standard:1.08025
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：22：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.5416648200092632
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.5416648200092632
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：23：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.5597351098233941
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.5597351098233941
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：24：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.5419757350908775
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.5419757350908775
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：25：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.6828588354183364
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.6828588354183364
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：26：
# judge_distence = 1
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# feature[0][0]:1.5879120005440168
# max_time_standard:1.08025
# Memory leak： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.
# Proceed to serial number：27：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.6087649634226506
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.6087649634226506
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：28：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.6090011100243555
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.6090011100243555
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：29：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.6192284907830087
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.6192284907830087
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：30：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.611468469861367
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.611468469861367
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：31：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.6952680348509079
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.6952680348509079
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：32：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.7069116185819634
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.7069116185819634
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：33：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.7029752780220252
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.7029752780220252
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.
# Proceed to serial number：34：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]:0.70510905541021
# min_time_standard:0.9257
# judge_dataseries[0][0]: 1
# feature[0][0] = 0.70510905541021
# Shutdown： The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.

# %%
def precisionRate2(result):
    num=0
    for i in result:
        if i[0]==2:
            num=num+1
    print("Accuracy:",(num/len(result)))
precisionRate2(SeriesResult2)
# Out:
# Accuracy: 0.7058823529411765

# %% [markdown]
# ### All result

# %%
def resultValue():
    Result_all_pre=[]
    Result_all_true=[]
    for i in SeriesResult:
        Result_all_pre.append(i[0])
        Result_all_true.append(0)

    for i in SeriesResult1:
        Result_all_pre.append(i[0])
        Result_all_true.append(1)

    for i in SeriesResult2:
        Result_all_pre.append(i[0])
        Result_all_true.append(2)
    
    return [Result_all_pre,Result_all_true]

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import classification_report

# %%
resultvalue = resultValue()
print(len(resultvalue[0]))
acc_num=0
for i in range(0,12):
    if(resultvalue[0][i]==resultvalue[1][i]):
        acc_num=acc_num+1

print("Accuracy:",acc_num/len(resultvalue[0]))

print(classification_report(resultvalue[1], resultvalue[0], labels=[0, 1, 2]))
# Out:
# 96
# Accuracy: 0.125
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85        30
#            1       0.71      0.91      0.79        32
#            2       1.00      0.71      0.83        34
#
#     accuracy                           0.82        96
#    macro avg       0.85      0.83      0.82        96
# weighted avg       0.85      0.82      0.82        96
